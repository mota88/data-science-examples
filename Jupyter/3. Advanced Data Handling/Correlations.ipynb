# %%
import pandas as pd
import numpy as np
df = pd.read_csv("Z:/csv/casos_diagnostico_ccaa.csv", nrows=1e6)

# %%
df.dtypes
# Out:
# ccaa_iso                        object
# fecha                           object
# num_casos                        int64
# num_casos_prueba_pcr             int64
# num_casos_prueba_test_ac         int64
# num_casos_prueba_ag              int64
# num_casos_prueba_elisa           int64
# num_casos_prueba_desconocida     int64
# dtype: object

# %%
df.groupby(by = 'ccaa_iso')['num_casos'].describe()
# Out:
#           count         mean          std  min    25%    50%     75%     max
# ccaa_iso
# AN        379.0   777.058047  1112.765175  0.0   12.0  211.0  1083.0  4677.0
# AR        379.0   224.910290   250.053089  0.0   12.5  169.0   349.5  1152.0
# AS        379.0    77.361478   122.837113  0.0    0.5   26.0    93.0   801.0
# CB        379.0    51.794195    62.018899  0.0    1.0   27.0    81.0   263.0
# CE        379.0     8.897098    14.779776  0.0    0.0    2.0    11.0    75.0
# CL        379.0   383.208443   470.435615  0.0   16.5  217.0   593.5  2033.0
# CM        379.0   300.021108   316.388348  0.0   22.5  146.0   555.5  1386.0
# CN        379.0    79.617414    87.992838  0.0    2.0   30.0   142.5   310.0
# CT        379.0  1090.688654  1198.153749  0.0  140.5  842.0  1440.0  5739.0
# EX        379.0   128.192612   205.652626  0.0    3.0   32.0   184.0  1491.0
# GA        379.0   184.728232   210.735742  0.0    6.0  105.0   310.0  1099.0
# ...

# %%
np.corrcoef(df["num_casos"],df["num_casos_prueba_pcr"]) #gives the correlation coefficient - always symmetric and with diagonal 1
# Out:
# array([[1.        , 0.96976446],
#        [0.96976446, 1.        ]])

# %%
np.corrcoef([df["num_casos"],df["num_casos_prueba_pcr"],df["num_casos_prueba_ag"]])
# Out:
# array([[1.        , 0.96976446, 0.584733  ],
#        [0.96976446, 1.        , 0.36929243],
#        [0.584733  , 0.36929243, 1.        ]])

# %%
df.corr() #correlations matrix
# Out:
#                               num_casos  num_casos_prueba_pcr  \
# num_casos                      1.000000              0.969764
# num_casos_prueba_pcr           0.969764              1.000000
# num_casos_prueba_test_ac       0.000905              0.002343
# num_casos_prueba_ag            0.584733              0.369292
# num_casos_prueba_elisa         0.145598              0.167886
# num_casos_prueba_desconocida   0.123331              0.144121
#
#                               num_casos_prueba_test_ac  num_casos_prueba_ag  \
# num_casos                                     0.000905             0.584733
# num_casos_prueba_pcr                          0.002343             0.369292
# num_casos_prueba_test_ac                      1.000000            -0.031760
# num_casos_prueba_ag                          -0.031760             1.000000
# num_casos_prueba_elisa                        0.006121            -0.024513
# ...

# %%
corr = round(df.corr(),3) #correlations matrix rounded to 3 decimal numbers
corr.style.background_gradient() #graph
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <style  type="text/css" >
# #T_a59eb3f9_566c_11eb_a1c0_080027deb9f1row0_col0,#T_a59eb3f9_566c_11eb_a1c0_080027deb9f1row1_col1,#T_a59eb3f9_566c_11eb_a1c0_080027deb9f1row2_col2,#T_a59eb3f9_566c_11eb_a1c0_080027deb9f1row3_col3,#T_a59eb3f9_566c_11eb_a1c0_080027deb9f1row4_col4,#T_a59eb3f9_566c_11eb_a1c0_080027deb9f1row5_col5{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_a59eb3f9_566c_11eb_a1c0_080027deb9f1row0_col1,#T_a59eb3f9_566c_11eb_a1c0_080027deb9f1row1_col0{
#             background-color:  #023f64;
#             color:  #f1f1f1;
#         }#T_a59eb3f9_566c_11eb_a1c0_080027deb9f1row0_col2,#T_a59eb3f9_566c_11eb_a1c0_080027deb9f1row1_col2{
#             background-color:  #faf3f9;
#             color:  #000000;
#         }#T_a59eb3f9_566c_11eb_a1c0_080027deb9f1row0_col3{
#             background-color:  #4295c3;
#             color:  #000000;
# ...
